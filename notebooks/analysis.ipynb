# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('/Users/sujal/OneDrive/Desktop/Review4/dataset/hormuz_trade_uncleaned.csv')
df
# Out:
#             date       vessel_name       mmsi              flag  trade_tier  \
# 0     2026-03-01     MarchVessel_1  100000001             India  Privileged
# 1     2026-03-01     MarchVessel_2  100000002              Iran  Privileged
# 2     2026-03-01     MarchVessel_3  100000003              Iran  Privileged
# 3     2026-03-02     MarchVessel_4  100000004            Greece       Taxed
# 4     2026-03-02     MarchVessel_5  100000005              Iran  Privileged
# ...          ...               ...        ...               ...         ...
# 1885  2026-05-31   Iron Carrier 15  386403601                UK     Blocked
# 1886  2026-05-31    Global Star 34  369408512              Iran  Privileged
# 1887  2026-05-31     Red Spirit 36  559556395           Liberia       Taxed
# 1888  2026-05-31  Eastern Titan 10  238114122            Russia  Privileged
# 1889  2026-05-31  Golden Trader 56  287324253  Marshall Islands       Taxed
#
# ...

# %%
df.isnull().sum()
# Out:
# date                                0
# vessel_name                         0
# mmsi                                0
# flag                                0
# trade_tier                          0
# transit_status                      0
# toll_usd                            0
# rerouted                            0
# commodity                           0
# destination                         0
# payment_rail                        0
# ship_hull_value_usd                 0
# insurance_premium_delta_pct         0
# insurance_cost_usd                  0
# days_delayed                        0
# extra_fuel_tonnes                   0
# reroute_penalty_usd                 0
# total_transit_cost_usd              0
# naval_escort_status              1211
# estimated_cargo_value_usd           0
# total_asset_value_at_risk_usd       0
# continent                           0
# inflation_premium_per_unit        499
# dtype: int64

# %%
df = df.drop(['naval_escort_status'], axis = 1)

# %%
df.isnull().sum()
# Out:
# date                               0
# vessel_name                        0
# mmsi                               0
# flag                               0
# trade_tier                         0
# transit_status                     0
# toll_usd                           0
# rerouted                           0
# commodity                          0
# destination                        0
# payment_rail                       0
# ship_hull_value_usd                0
# insurance_premium_delta_pct        0
# insurance_cost_usd                 0
# days_delayed                       0
# extra_fuel_tonnes                  0
# reroute_penalty_usd                0
# total_transit_cost_usd             0
# estimated_cargo_value_usd          0
# total_asset_value_at_risk_usd      0
# continent                          0
# inflation_premium_per_unit       499
# dtype: int64

# %%
df.dtypes
# Out:
# date                                 str
# vessel_name                          str
# mmsi                               int64
# flag                                 str
# trade_tier                           str
# transit_status                       str
# toll_usd                           int64
# rerouted                             str
# commodity                            str
# destination                          str
# payment_rail                         str
# ship_hull_value_usd                int64
# insurance_premium_delta_pct      float64
# insurance_cost_usd                 int64
# days_delayed                       int64
# extra_fuel_tonnes                  int64
# reroute_penalty_usd                int64
# total_transit_cost_usd             int64
# estimated_cargo_value_usd          int64
# total_asset_value_at_risk_usd      int64
# continent                            str
# inflation_premium_per_unit       float64
# dtype: object

# %%
df['inflation_premium_per_unit'] = df['inflation_premium_per_unit'].fillna(
    df['inflation_premium_per_unit'].mode()[0]
)

# %%
df
# Out:
#             date       vessel_name       mmsi              flag  trade_tier  \
# 0     2026-03-01     MarchVessel_1  100000001             India  Privileged
# 1     2026-03-01     MarchVessel_2  100000002              Iran  Privileged
# 2     2026-03-01     MarchVessel_3  100000003              Iran  Privileged
# 3     2026-03-02     MarchVessel_4  100000004            Greece       Taxed
# 4     2026-03-02     MarchVessel_5  100000005              Iran  Privileged
# ...          ...               ...        ...               ...         ...
# 1885  2026-05-31   Iron Carrier 15  386403601                UK     Blocked
# 1886  2026-05-31    Global Star 34  369408512              Iran  Privileged
# 1887  2026-05-31     Red Spirit 36  559556395           Liberia       Taxed
# 1888  2026-05-31  Eastern Titan 10  238114122            Russia  Privileged
# 1889  2026-05-31  Golden Trader 56  287324253  Marshall Islands       Taxed
#
# ...

# %%
df.isnull().sum()
# Out:
# date                             0
# vessel_name                      0
# mmsi                             0
# flag                             0
# trade_tier                       0
# transit_status                   0
# toll_usd                         0
# rerouted                         0
# commodity                        0
# destination                      0
# payment_rail                     0
# ship_hull_value_usd              0
# insurance_premium_delta_pct      0
# insurance_cost_usd               0
# days_delayed                     0
# extra_fuel_tonnes                0
# reroute_penalty_usd              0
# total_transit_cost_usd           0
# estimated_cargo_value_usd        0
# total_asset_value_at_risk_usd    0
# continent                        0
# inflation_premium_per_unit       0
# dtype: int64

# %%
df.dtypes
# Out:
# date                                 str
# vessel_name                          str
# mmsi                               int64
# flag                                 str
# trade_tier                           str
# transit_status                       str
# toll_usd                           int64
# rerouted                             str
# commodity                            str
# destination                          str
# payment_rail                         str
# ship_hull_value_usd                int64
# insurance_premium_delta_pct      float64
# insurance_cost_usd                 int64
# days_delayed                       int64
# extra_fuel_tonnes                  int64
# reroute_penalty_usd                int64
# total_transit_cost_usd             int64
# estimated_cargo_value_usd          int64
# total_asset_value_at_risk_usd      int64
# continent                            str
# inflation_premium_per_unit       float64
# dtype: object

# %%
# datatype change for date
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date                             datetime64[us]
# vessel_name                                 str
# mmsi                                      int64
# flag                                        str
# trade_tier                                  str
# transit_status                              str
# toll_usd                                  int64
# rerouted                                    str
# commodity                                   str
# destination                                 str
# payment_rail                                str
# ship_hull_value_usd                       int64
# insurance_premium_delta_pct             float64
# insurance_cost_usd                        int64
# days_delayed                              int64
# extra_fuel_tonnes                         int64
# reroute_penalty_usd                       int64
# total_transit_cost_usd                    int64
# estimated_cargo_value_usd                 int64
# total_asset_value_at_risk_usd             int64
# ...

# %%
df
# Out:
#            date       vessel_name       mmsi              flag  trade_tier  \
# 0    2026-03-01     MarchVessel_1  100000001             India  Privileged
# 1    2026-03-01     MarchVessel_2  100000002              Iran  Privileged
# 2    2026-03-01     MarchVessel_3  100000003              Iran  Privileged
# 3    2026-03-02     MarchVessel_4  100000004            Greece       Taxed
# 4    2026-03-02     MarchVessel_5  100000005              Iran  Privileged
# ...         ...               ...        ...               ...         ...
# 1885 2026-05-31   Iron Carrier 15  386403601                UK     Blocked
# 1886 2026-05-31    Global Star 34  369408512              Iran  Privileged
# 1887 2026-05-31     Red Spirit 36  559556395           Liberia       Taxed
# 1888 2026-05-31  Eastern Titan 10  238114122            Russia  Privileged
# 1889 2026-05-31  Golden Trader 56  287324253  Marshall Islands       Taxed
#
# ...

# %%
df.insert(0, 'vessel_id', range(1, len(df) + 1))

# %%
df
# Out:
#       vessel_id       date       vessel_name       mmsi              flag  \
# 0             1 2026-03-01     MarchVessel_1  100000001             India
# 1             2 2026-03-01     MarchVessel_2  100000002              Iran
# 2             3 2026-03-01     MarchVessel_3  100000003              Iran
# 3             4 2026-03-02     MarchVessel_4  100000004            Greece
# 4             5 2026-03-02     MarchVessel_5  100000005              Iran
# ...         ...        ...               ...        ...               ...
# 1885       1886 2026-05-31   Iron Carrier 15  386403601                UK
# 1886       1887 2026-05-31    Global Star 34  369408512              Iran
# 1887       1888 2026-05-31     Red Spirit 36  559556395           Liberia
# 1888       1889 2026-05-31  Eastern Titan 10  238114122            Russia
# 1889       1890 2026-05-31  Golden Trader 56  287324253  Marshall Islands
#
#       trade_tier transit_status  toll_usd                 rerouted  \
# ...

# %%
df['rerouted'] = df['rerouted'].map({
    'Yes (Cape of Good Hope)': 1,
    'No': 0
}).astype(int)

# %%
df
# Out:
#       vessel_id       date       vessel_name       mmsi              flag  \
# 0             1 2026-03-01     MarchVessel_1  100000001             India
# 1             2 2026-03-01     MarchVessel_2  100000002              Iran
# 2             3 2026-03-01     MarchVessel_3  100000003              Iran
# 3             4 2026-03-02     MarchVessel_4  100000004            Greece
# 4             5 2026-03-02     MarchVessel_5  100000005              Iran
# ...         ...        ...               ...        ...               ...
# 1885       1886 2026-05-31   Iron Carrier 15  386403601                UK
# 1886       1887 2026-05-31    Global Star 34  369408512              Iran
# 1887       1888 2026-05-31     Red Spirit 36  559556395           Liberia
# 1888       1889 2026-05-31  Eastern Titan 10  238114122            Russia
# 1889       1890 2026-05-31  Golden Trader 56  287324253  Marshall Islands
#
#       trade_tier transit_status  toll_usd  rerouted         commodity  ...  \
# ...

# %%
df.dtypes
# Out:
# vessel_id                                 int64
# date                             datetime64[us]
# vessel_name                                 str
# mmsi                                      int64
# flag                                        str
# trade_tier                                  str
# transit_status                              str
# toll_usd                                  int64
# rerouted                                  int64
# commodity                                   str
# destination                                 str
# payment_rail                                str
# ship_hull_value_usd                       int64
# insurance_premium_delta_pct             float64
# insurance_cost_usd                        int64
# days_delayed                              int64
# extra_fuel_tonnes                         int64
# reroute_penalty_usd                       int64
# total_transit_cost_usd                    int64
# estimated_cargo_value_usd                 int64
# ...

# %%
df
# Out:
#       vessel_id       date       vessel_name       mmsi              flag  \
# 0             1 2026-03-01     MarchVessel_1  100000001             India
# 1             2 2026-03-01     MarchVessel_2  100000002              Iran
# 2             3 2026-03-01     MarchVessel_3  100000003              Iran
# 3             4 2026-03-02     MarchVessel_4  100000004            Greece
# 4             5 2026-03-02     MarchVessel_5  100000005              Iran
# ...         ...        ...               ...        ...               ...
# 1885       1886 2026-05-31   Iron Carrier 15  386403601                UK
# 1886       1887 2026-05-31    Global Star 34  369408512              Iran
# 1887       1888 2026-05-31     Red Spirit 36  559556395           Liberia
# 1888       1889 2026-05-31  Eastern Titan 10  238114122            Russia
# 1889       1890 2026-05-31  Golden Trader 56  287324253  Marshall Islands
#
#       trade_tier transit_status  toll_usd  rerouted         commodity  ...  \
# ...

# %%
df['rerouted'] = df['rerouted'].astype(bool)
df.dtypes
# Out:
# vessel_id                                 int64
# date                             datetime64[us]
# vessel_name                                 str
# mmsi                                      int64
# flag                                        str
# trade_tier                                  str
# transit_status                              str
# toll_usd                                  int64
# rerouted                                   bool
# commodity                                   str
# destination                                 str
# payment_rail                                str
# ship_hull_value_usd                       int64
# insurance_premium_delta_pct             float64
# insurance_cost_usd                        int64
# days_delayed                              int64
# extra_fuel_tonnes                         int64
# reroute_penalty_usd                       int64
# total_transit_cost_usd                    int64
# estimated_cargo_value_usd                 int64
# ...

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
outlier_summary = {}
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    outlier_summary[col] = len(outliers)
print("Outlier count per column:\n")
print(outlier_summary)
# Out:
# Outlier count per column:
#
# {'vessel_id': 0, 'mmsi': 0, 'toll_usd': 422, 'ship_hull_value_usd': 0, 'insurance_premium_delta_pct': 422, 'insurance_cost_usd': 290, 'days_delayed': 0, 'extra_fuel_tonnes': 0, 'reroute_penalty_usd': 0, 'total_transit_cost_usd': 0, 'estimated_cargo_value_usd': 0, 'total_asset_value_at_risk_usd': 0, 'inflation_premium_per_unit': 284}

# %%
df
# Out:
#       vessel_id       date       vessel_name       mmsi              flag  \
# 0             1 2026-03-01     MarchVessel_1  100000001             India
# 1             2 2026-03-01     MarchVessel_2  100000002              Iran
# 2             3 2026-03-01     MarchVessel_3  100000003              Iran
# 3             4 2026-03-02     MarchVessel_4  100000004            Greece
# 4             5 2026-03-02     MarchVessel_5  100000005              Iran
# ...         ...        ...               ...        ...               ...
# 1885       1886 2026-05-31   Iron Carrier 15  386403601                UK
# 1886       1887 2026-05-31    Global Star 34  369408512              Iran
# 1887       1888 2026-05-31     Red Spirit 36  559556395           Liberia
# 1888       1889 2026-05-31  Eastern Titan 10  238114122            Russia
# 1889       1890 2026-05-31  Golden Trader 56  287324253  Marshall Islands
#
#       trade_tier transit_status  toll_usd  rerouted         commodity  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# vessel_id                        0
# date                             0
# vessel_name                      0
# mmsi                             0
# flag                             0
# trade_tier                       0
# transit_status                   0
# toll_usd                         0
# rerouted                         0
# commodity                        0
# destination                      0
# payment_rail                     0
# ship_hull_value_usd              0
# insurance_premium_delta_pct      0
# insurance_cost_usd               0
# days_delayed                     0
# extra_fuel_tonnes                0
# reroute_penalty_usd              0
# total_transit_cost_usd           0
# estimated_cargo_value_usd        0
# total_asset_value_at_risk_usd    0
# continent                        0
# inflation_premium_per_unit       0
# dtype: int64

# %%
df.to_csv("Cleaned.csv", index=False)
